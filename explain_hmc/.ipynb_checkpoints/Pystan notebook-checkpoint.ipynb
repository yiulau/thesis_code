# %%
import pystan

code = """
parameters {
    real y;
}
model {
    y ~ normal(0,1);
}

"""

fit = pystan.stan(model_code=code,iter=100,chains=1,thin=1)

# %%
fit
# Out:
# Inference for Stan model: anon_model_306a6e2ed1ff83e388e1087b425595da.
# 4 chains, each with iter=100; warmup=50; thin=1;
# post-warmup draws per chain=50, total post-warmup draws=200.
#
#        mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# y   -4.6e-3     0.1   1.07  -2.21  -0.77   0.08   0.78   2.04  118.0   1.01
# lp__  -0.57    0.07   0.76  -2.92  -0.71   -0.3  -0.05-3.1e-3  123.0   1.02
#
# Samples were drawn using NUTS at Tue Apr 11 10:46:40 2017.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
# %matplotlib inline
fit.plot()
